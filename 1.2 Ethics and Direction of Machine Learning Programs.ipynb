# %% [markdown]
# ### Importing Libraries & Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
#path
path=r"C:\Users\nabar\OneDrive\Documents\2025 Climet Wins"
#df
df = pd.read_csv(os.path.join(path, '02 Data','Original Data','Dataset-weather-prediction-dataset-processed.csv'))

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %% [markdown]
# ### Cleaning Data

# %%
print(df.info())  # Quick overview
print(df.isnull().sum())  # Missing value count per column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB
# None
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
# BASEL_humidity         0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 170, dtype: int64

# %%
print(df.duplicated().sum())  # Count duplicates
df = df.drop_duplicates()     # Remove duplicates
# Out:
# 0

# %%
print(df.dtypes)  # Data types
# Out:
# DATE                     int64
# MONTH                    int64
# BASEL_cloud_cover        int64
# BASEL_wind_speed       float64
# BASEL_humidity         float64
#                         ...
# VALENTIA_snow_depth      int64
# VALENTIA_sunshine      float64
# VALENTIA_temp_mean     float64
# VALENTIA_temp_min      float64
# VALENTIA_temp_max      float64
# Length: 170, dtype: object

# %% [markdown]
# #### No duplicate or missing values.

# %% [markdown]
# ### Scaling Data

# %%
# Separate date columns (keep them unchanged)
date_cols = ['DATE', 'MONTH']
df_dates = df[date_cols]

# Scale only the numeric feature columns
df_features = df.drop(columns=date_cols)
scaler = StandardScaler()
scaled_array = scaler.fit_transform(df_features)

# Reconstruct full DataFrame
scaled_df = pd.DataFrame(scaled_array, columns=df_features.columns)
final_df = pd.concat([df_dates.reset_index(drop=True), scaled_df], axis=1)

# Save scaled file using the defined path
save_path = os.path.join(path, '02 Data', 'Prepared Data', 'climate_data_scaled.csv')
final_df.to_csv(save_path, index=False)

# %%
final_df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1           0.660514          -0.02793        0.826097
# 1  19600102      1           0.244897          -0.02793        0.735760
# 2  19600103      1           1.076130          -0.02793        1.277781
# 3  19600104      1          -1.001953          -0.02793        1.458455
# 4  19600105      1           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0         -0.179228       -0.902918  ...             -0.443701
# ...
